# %% [markdown]
# ## Reserve and configure resources on KVM

# %% [markdown]
# ## Create lease and reserve resources

# %%
import json
import os
import chi
import chi.ssh
import chi.network
from datetime import datetime, timedelta
from dateutil import tz
import chi.server

# %%
import chi,os

site_name = "KVM@TACC"
chi.use_site(site_name)
os.environ["OS_REGION_NAME"] = site_name
project = "CHI-231095"
#os.getenv("OS_PROJECT_NAME")
print(project)
chi.set('project_name', project)
# Out:
# Now using KVM@TACC:
# URL: https://kvm.tacc.chameleoncloud.org
# Location: Austin, Texas, USA
# Support contact: help@chameleoncloud.org
# CHI-231095

# %%
username = os.getenv("USER")
suffix = username + "_k8s-ml"
server_prefix = "node" 
network_name = "net-" + suffix
subnet_name = "subnet-" + suffix
router_name = "router-" + suffix
lease_name = "lease-" + suffix

# %%
#Server attributes
image_name='CC-Ubuntu20.04'
node_type="compute_cascadelake_r"
server_count=3
physical_network="physnet1"
subnet_cidr = '192.168.1.0/24'

# %% [markdown]
# #### Create the Network

# %%
os_conn = chi.clients.connection()

# %%
network = os_conn.create_network(
                network_name,
            )
network_id = network['id']

print(f'Network ID: {network_id}')
# Out:
# Network ID: 8a4089dd-5f31-49b9-aaec-25d7e87bc398

# %% [markdown]
# #### Configure the Network

# %%
subnet = chi.network.create_subnet(subnet_name, network_id, cidr=subnet_cidr, gateway_ip=None)
router = chi.network.create_router(router_name, gw_network_name='public')
chi.network.add_subnet_to_router(router['id'], subnet['id'])
# Out:
# {'network_id': '8a4089dd-5f31-49b9-aaec-25d7e87bc398',
#  'tenant_id': '287158fd03da48e48eb0d2682f38fcc9',
#  'subnet_id': 'a5a89372-e36f-4759-8fd1-0373033907d1',
#  'subnet_ids': ['a5a89372-e36f-4759-8fd1-0373033907d1'],
#  'port_id': 'b7271a63-a2b3-4882-ba4d-948c90c7c086',
#  'id': '696dce19-c36f-4d84-be36-4fbdb1ee205d'}

# %% [markdown]
# #### Start the server

# %%
servers = []
for i in range(server_count):
    servers.append(chi.server.create_server(server_prefix+f"-{i}-" + suffix, 
                                  network_id=network_id,
                                  nics=[{"net-id": network_id,"v4-fixed-ip": f"192.168.1.2{i}" }],
                                  image_name=image_name,
                                            flavor_name= "m1.large",
                                            
                                  count=1))

# %% [markdown]
# #### Associate floating ips

# %%
nodes = {}

for j,i in enumerate(servers):
    chi.server.wait_for_active(i.id)
    floating_ip = chi.server.associate_floating_ip(i.id)
    nodes[j] = floating_ip

    print(f'Floating IP of node_{j}: {floating_ip}')
# Out:
# Floating IP of node_0: 129.114.26.122
# Floating IP of node_1: 129.114.27.104
# Floating IP of node_2: 129.114.25.34

# %% [markdown]
# #### Create and add security groups to all servers

# %%
# %%bash
# export OS_AUTH_URL=https://kvm.tacc.chameleoncloud.org:5000/v3
#
# access_token=$(curl -s -H"authorization: token $JUPYTERHUB_API_TOKEN"     "$JUPYTERHUB_API_URL/users/$JUPYTERHUB_USER"     | jq -r .auth_state.access_token)
# export OS_ACCESS_TOKEN="$access_token"
# SECURITY_GROUP_NAME="Allow SSH"
#
# if ! openstack security group show "$SECURITY_GROUP_NAME" > /dev/null 2>&1; then
#     echo "Security group does not exist yet - creating it for you now"
#     openstack security group create "$SECURITY_GROUP_NAME"  --description "Enable SSH traffic on TCP port 22"
#     openstack security group rule create "$SECURITY_GROUP_NAME" \
#      --protocol tcp --dst-port 22:22 --remote-ip 0.0.0.0/0
#
# else
#     echo "Security group already exists"
# fi

# %%
# %%bash
# export OS_AUTH_URL=https://kvm.tacc.chameleoncloud.org:5000/v3
#
# access_token=$(curl -s -H"authorization: token $JUPYTERHUB_API_TOKEN"     "$JUPYTERHUB_API_URL/users/$JUPYTERHUB_USER"     | jq -r .auth_state.access_token)
# export OS_ACCESS_TOKEN="$access_token"
# SECURITY_GROUP_NAME="Allow http"
#
# if ! openstack security group show "$SECURITY_GROUP_NAME" > /dev/null 2>&1; then
#     echo "Security group does not exist yet - creating it for you now"
#     openstack security group create "$SECURITY_GROUP_NAME"  --description "Enable http traffic on TCP port 32000"
#     openstack security group rule create "$SECURITY_GROUP_NAME" \
#      --protocol tcp --dst-port 5000:5000 --remote-ip 0.0.0.0/0
#
# else
#     echo "Security group already exists"
# fi

# %%
for j,i in enumerate(servers):
    nova_server = chi.nova().servers.get(i.id)
    nova_server.add_security_group("Allow SSH")
    nova_server.add_security_group("Allow http")
    print(f"updated security groups: {[group.name for group in nova_server.list_security_group()]}")
# Out:
# updated security groups: ['Allow SSH', 'Allow http', 'default']
# updated security groups: ['Allow SSH', 'Allow http', 'default']
# updated security groups: ['Allow SSH', 'Allow http', 'default']

# %% [markdown]
# #### Wait for SSH access to all servers

# %%
for node_ip in nodes.values():
    chi.server.wait_for_tcp(node_ip, port=22)

# %% [markdown]
# ### Configuring the servers

# %% [markdown]
# #### Add your public keys to each of the server

# %%
from chi.ssh import Remote
for node_ip in nodes.values():
    remote = Remote(node_ip)
    nova=chi.clients.nova()
    [kp.name for kp in nova.keypairs.list()]
    keypair_name = 'id_rsa_chameleon' # The name of the key they uploaded 
    public_key = nova.keypairs.get(keypair_name).public_key # Contents of the public key
    remote.run(f"echo {public_key} >> ~/.ssh/authorized_keys")
# Out:
# /opt/conda/lib/python3.10/site-packages/paramiko/client.py:835: UserWarning: Unknown ssh-ed25519 host key for 129.114.26.122: b'bc02df4a10b1e53395b677dbc744efab'
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/paramiko/client.py:835: UserWarning: Unknown ssh-ed25519 host key for 129.114.27.104: b'c81e5deb6e04f04bc70ee256ff87fa4a'
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/paramiko/client.py:835: UserWarning: Unknown ssh-ed25519 host key for 129.114.25.34: b'f4854d6c5ddea191fdb5317bad52d2e8'
#   warnings.warn(

# %% [markdown]
# #### Install keys for SSH access between all servers

# %%
for node_ip in nodes.values():
    remote = chi.ssh.Remote(node_ip)
    remote.run('ssh-keygen -t rsa -b 4096 -f ~/.ssh/id_rsa -q -N ""')
    public_key = remote.run('cat ~/.ssh/id_rsa.pub').tail("stdout")[2:]
    public_key = public_key.replace("\n", "")
    for other_node_ip in nodes.values():
        remote = chi.ssh.Remote(other_node_ip)
        remote.run(f'echo {public_key} >> ~/.ssh/authorized_keys')
# Out:
# ssh-rsa ... cc@node-0-cp3793-nyu-edu-k8s-ml
# ssh-rsa ... cc@node-1-cp3793-nyu-edu-k8s-ml
# ssh-rsa ... cc@node-2-cp3793-nyu-edu-k8s-ml

# %% [markdown]
# #### Store the IP address of each host

# %%
physical_ips=[]
for node_ip in nodes.values():
    chi.server.wait_for_tcp(node_ip, port=22)
    remote = chi.ssh.Remote(node_ip)
    physical_ips.append(remote.run('hostname -I').tail("stdout")[2:-1])
# Out:
# 192.168.1.20
# 192.168.1.21
# 192.168.1.22

# %% [markdown]
# #### Use Kubespray to prepare a Kubernetes cluster

# %%
ansible_node = nodes[0]
remote = chi.ssh.Remote(ansible_node)
remote.run("sudo apt install virtualenv")
remote.run("virtualenv -p python3 myenv")
remote.run("git clone https://github.com/kubernetes-sigs/kubespray.git")
remote.run("source myenv/bin/activate; cd kubespray; pip3 install -r requirements.txt")
remote.run("cd kubespray; cp -rfp inventory/sample inventory/mycluster")
remote.run("rm -rf kubespray/contrib/inventory_builder/inventory.py")
remote.run("rm -rf kubespray/inventory/mycluster/group_vars/k8s_cluster/addons.yml")
remote.run("rm -rf kubespray/inventory/mycluster/group_vars/k8s_cluster/k8s-cluster.yml")
remote.run("wget https://raw.githubusercontent.com/indianspeedster/kubespray/master/inventory/sample/group_vars/k8s_cluster/k8s-cluster.yml -O kubespray/inventory/mycluster/group_vars/k8s_cluster/k8s-cluster.yml")
remote.run("wget https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/inventory.py -O kubespray/contrib/inventory_builder/inventory.py")
remote.run("wget https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/addons.yml -O kubespray/inventory/mycluster/group_vars/k8s_cluster/addons.yml")
remote.run(f"source myenv/bin/activate; declare -a IPS=({physical_ips[0]} {physical_ips[1]} {physical_ips[2]});"+"cd kubespray; CONFIG_FILE=inventory/mycluster/hosts.yaml python3 contrib/inventory_builder/inventory.py ${IPS[@]}")
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   virtualenv
# 0 upgraded, 1 newly installed, 0 to remove and 0 not upgraded.
# Need to get 2144 B of archives.
# After this operation, 23.6 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu focal-updates/universe amd64 virtualenv all 20.0.17-1ubuntu0.4 [2144 B]
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Fetched 2144 B in 0s (15.1 kB/s)
# Selecting previously unselected package virtualenv.
# (Reading database ... 82514 files and directories currently installed.)
# Preparing to unpack .../virtualenv_20.0.17-1ubuntu0.4_all.deb ...
# Unpacking virtualenv (20.0.17-1ubuntu0.4) ...
# Setting up virtualenv (20.0.17-1ubuntu0.4) ...
# created virtual environment CPython3.8.10.final.0-64 in 1681ms
#   creator CPython3Posix(dest=/home/cc/myenv, clear=False, global=False)
#   seeder FromAppData(download=False, pip=latest, setuptools=latest, wheel=latest, pkg_resources=latest, via=copy, app_data_dir=/home/cc/.local/share/virtualenv/seed-app-data/v1.0.1.debian.1)
#   activators BashActivator,CShellActivator,FishActivator,PowerShellActivator,PythonActivator,XonshActivator
# Cloning into 'kubespray'...
# Collecting ansible==5.7.1
#   Downloading ansible-5.7.1.tar.gz (35.7 MB)
# Collecting ansible-core==2.12.10
#   Downloading ansible-core-2.12.10.tar.gz (7.8 MB)
# Collecting cryptography==3.4.8
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting jinja2==3.1.2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting jmespath==1.0.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting MarkupSafe==2.1.2
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting netaddr==0.8.0
#   Downloading netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
# Collecting pbr==5.11.1
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Collecting ruamel.yaml==0.17.21
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
# Collecting ruamel.yaml.clib==0.2.7
#   Downloading ruamel.yaml.clib-0.2.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (555 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting packaging
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
# Collecting resolvelib<0.6.0,>=0.5.3
#   Downloading resolvelib-0.5.4-py2.py3-none-any.whl (12 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (442 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: ansible, ansible-core
#   Building wheel for ansible (setup.py): started
#   Building wheel for ansible (setup.py): finished with status 'done'
#   Created wheel for ansible: filename=ansible-5.7.1-py3-none-any.whl size=61777681 sha256=4129d6cb0decbed67ea4460473971bfb51a767db73e13b12ebfb60be11be050c
#   Stored in directory: /home/cc/.cache/pip/wheels/02/07/2a/7b3eb5d79e268b769b0910cded0d524b4647ae5bc19f3ebb70
#   Building wheel for ansible-core (setup.py): started
#   Building wheel for ansible-core (setup.py): finished with status 'done'
#   Created wheel for ansible-core: filename=ansible_core-2.12.10-py3-none-any.whl size=2079008 sha256=237ef2aff39f9aa00a4fb2ee37eeaf32b7ad02987012ba00cf23bcfa9c05a774
#   Stored in directory: /home/cc/.cache/pip/wheels/eb/61/b4/118d4eac8be0248f90ddde117bee70e10d3a37be86786289a5
# Successfully built ansible ansible-core
# Installing collected packages: PyYAML, pycparser, cffi, cryptography, MarkupSafe, jinja2, packaging, resolvelib, ansible-core, ansible, jmespath, netaddr, pbr, ruamel.yaml.clib, ruamel.yaml
# Successfully installed MarkupSafe-2.1.2 PyYAML-6.0 ansible-5.7.1 ansible-core-2.12.10 cffi-1.15.1 cryptography-3.4.8 jinja2-3.1.2 jmespath-1.0.1 netaddr-0.8.0 packaging-23.1 pbr-5.11.1 pycparser-2.21 resolvelib-0.5.4 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.7
# --2023-06-03 20:07:38--  https://raw.githubusercontent.com/indianspeedster/kubespray/master/inventory/sample/group_vars/k8s_cluster/k8s-cluster.yml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15449 (15K) [text/plain]
# Saving to: ‘kubespray/inventory/mycluster/group_vars/k8s_cluster/k8s-cluster.yml’
#
#      0K .......... .....                                      100% 34.6M=0s
#
# 2023-06-03 20:07:38 (34.6 MB/s) - ‘kubespray/inventory/mycluster/group_vars/k8s_cluster/k8s-cluster.yml’ saved [15449/15449]
#
# --2023-06-03 20:07:38--  https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/inventory.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17940 (18K) [text/plain]
# Saving to: ‘kubespray/contrib/inventory_builder/inventory.py’
#
#      0K .......... .......                                    100% 25.1M=0.001s
#
# 2023-06-03 20:07:38 (25.1 MB/s) - ‘kubespray/contrib/inventory_builder/inventory.py’ saved [17940/17940]
#
# --2023-06-03 20:07:39--  https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/addons.yml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5767 (5.6K) [text/plain]
# Saving to: ‘kubespray/inventory/mycluster/group_vars/k8s_cluster/addons.yml’
#
#      0K .....                                                 100% 20.3M=0s
#
# 2023-06-03 20:07:39 (20.3 MB/s) - ‘kubespray/inventory/mycluster/group_vars/k8s_cluster/addons.yml’ saved [5767/5767]
# DEBUG: Adding group all
# DEBUG: Adding group kube_control_plane
# DEBUG: Adding group kube_node
# DEBUG: Adding group etcd
# DEBUG: Adding group k8s_cluster
# DEBUG: Adding group calico_rr
# DEBUG: adding host node-0 to group all
# DEBUG: adding host node-1 to group all
# DEBUG: adding host node-2 to group all
# DEBUG: adding host node-0 to group etcd
# DEBUG: adding host node-1 to group etcd
# DEBUG: adding host node-2 to group etcd
# DEBUG: adding host node-0 to group kube_control_plane
# DEBUG: adding host node-1 to group kube_control_plane
# DEBUG: adding host node-0 to group kube_node
# DEBUG: adding host node-1 to group kube_node
# DEBUG: adding host node-2 to group kube_node
# <Result cmd='source myenv/bin/activate; declare -a IPS=(192.168.1.20 192.168.1.21 192.168.1.22);cd kubespray; CONFIG_FILE=inventory/mycluster/hosts.yaml python3 contrib/inventory_builder/inventory.py ${IPS[@]}' exited=0>

# %%
remote.run("source myenv/bin/activate; cd kubespray; ansible-playbook -i inventory/mycluster/hosts.yaml  --become --become-user=root cluster.yml")
# Out:
# [WARNING]: Skipping callback plugin 'ara_default', unable to load
# PLAY [localhost] ***************************************************************
# Saturday 03 June 2023  20:08:17 +0000 (0:00:00.043)       0:00:00.043 *********
#
# TASK [Check 2.12.0 <= Ansible version < 2.13.0] ********************************
# ok: [localhost] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:17 +0000 (0:00:00.060)       0:00:00.103 *********
#
# TASK [Check that python netaddr is installed] **********************************
# ok: [localhost] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.138)       0:00:00.241 *********
#
# TASK [Check that jinja is not too old (install via pip)] ***********************
# ok: [localhost] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# [WARNING]: Could not match supplied host pattern, ignoring: kube-master
# PLAY [Add kube-master nodes to kube_control_plane] *****************************
# skipping: no hosts matched
# [WARNING]: Could not match supplied host pattern, ignoring: kube-node
# PLAY [Add kube-node nodes to kube_node] ****************************************
# skipping: no hosts matched
#
# PLAY [Add k8s-cluster nodes to k8s_cluster] ************************************
# skipping: no hosts matched
#
# PLAY [Add calico-rr nodes to calico_rr] ****************************************
# skipping: no hosts matched
# [WARNING]: Could not match supplied host pattern, ignoring: k8s-cluster
# [WARNING]: Could not match supplied host pattern, ignoring: calico-rr
# PLAY [Add no-floating nodes to no_floating] ************************************
# skipping: no hosts matched
# [WARNING]: Could not match supplied host pattern, ignoring: no-floating
# PLAY [bastion[0]] **************************************************************
# skipping: no hosts matched
#
# PLAY [k8s_cluster:etcd:calico_rr] **********************************************
# [WARNING]: Could not match supplied host pattern, ignoring: bastion
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.088)       0:00:00.329 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.089)       0:00:00.419 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.061)       0:00:00.480 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.047)       0:00:00.528 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.077)       0:00:00.605 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.082)       0:00:00.688 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.080)       0:00:00.769 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.085)       0:00:00.854 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.046)       0:00:00.901 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.079)       0:00:00.981 *********
# Saturday 03 June 2023  20:08:18 +0000 (0:00:00.123)       0:00:01.104 *********
#
# TASK [kubespray-defaults : Configure defaults] *********************************
# ok: [node-0] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# ok: [node-1] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# ok: [node-2] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.142)       0:00:01.246 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.049)       0:00:01.296 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.032)       0:00:01.329 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.071)       0:00:01.401 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.032)       0:00:01.434 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.063)       0:00:01.497 *********
# Saturday 03 June 2023  20:08:19 +0000 (0:00:00.085)       0:00:01.583 *********
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# TASK [bootstrap-os : Fetch /etc/os-release] ************************************
# ok: [node-1]
# ok: [node-2]
# ok: [node-0]
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.946)       0:00:02.529 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.073)       0:00:02.603 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.063)       0:00:02.666 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.064)       0:00:02.731 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.073)       0:00:02.804 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.067)       0:00:02.871 *********
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.064)       0:00:02.936 *********
#
# TASK [bootstrap-os : include_tasks] ********************************************
# included: /home/cc/kubespray/roles/bootstrap-os/tasks/bootstrap-debian.yml for node-0, node-1, node-2
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.111)       0:00:03.048 *********
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# TASK [bootstrap-os : Check if bootstrap is needed] *****************************
# ok: [node-0]
# [WARNING]: raw module does not support the environment keyword
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:20 +0000 (0:00:00.139)       0:00:03.187 *********
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# TASK [bootstrap-os : Check http::proxy in apt configuration files] *************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.147)       0:00:03.335 *********
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.072)       0:00:03.407 *********
# [WARNING]: raw module does not support the environment keyword
# [WARNING]: raw module does not support the environment keyword
# TASK [bootstrap-os : Check https::proxy in apt configuration files] ************
# ok: [node-0]
# [WARNING]: raw module does not support the environment keyword
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.144)       0:00:03.551 *********
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.064)       0:00:03.616 *********
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.067)       0:00:03.683 *********
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.067)       0:00:03.751 *********
#
# TASK [bootstrap-os : Set the ansible_python_interpreter fact] ******************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:21 +0000 (0:00:00.091)       0:00:03.843 *********
#
# TASK [bootstrap-os : Install dbus for the hostname module] *********************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:24 +0000 (0:00:03.025)       0:00:06.868 *********
# Saturday 03 June 2023  20:08:24 +0000 (0:00:00.064)       0:00:06.932 *********
# Saturday 03 June 2023  20:08:24 +0000 (0:00:00.061)       0:00:06.994 *********
#
# TASK [bootstrap-os : Create remote_tmp for it is used by another module] *******
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:08:25 +0000 (0:00:00.651)       0:00:07.645 *********
#
# TASK [bootstrap-os : Gather host facts to get ansible_os_family] ***************
# ok: [node-2]
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:08:26 +0000 (0:00:01.418)       0:00:09.064 *********
#
# TASK [bootstrap-os : Assign inventory name to unconfigured hostnames (non-CoreOS, non-Flatcar, Suse and ClearLinux, non-Fedora)] ***
# changed: [node-1]
# changed: [node-0]
# changed: [node-2]
# Saturday 03 June 2023  20:08:28 +0000 (0:00:01.316)       0:00:10.380 *********
# Saturday 03 June 2023  20:08:28 +0000 (0:00:00.073)       0:00:10.454 *********
# Saturday 03 June 2023  20:08:28 +0000 (0:00:00.073)       0:00:10.528 *********
# Saturday 03 June 2023  20:08:28 +0000 (0:00:00.074)       0:00:10.602 *********
#
# TASK [bootstrap-os : Ensure bash_completion.d folder exists] *******************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
#
# PLAY [Gather facts] ************************************************************
# Saturday 03 June 2023  20:08:28 +0000 (0:00:00.536)       0:00:11.138 *********
#
# TASK [Gather minimal facts] ****************************************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:29 +0000 (0:00:00.786)       0:00:11.924 *********
#
# TASK [Gather necessary facts (network)] ****************************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:30 +0000 (0:00:00.751)       0:00:12.676 *********
#
# TASK [Gather necessary facts (hardware)] ***************************************
# ok: [node-0]
# ok: [node-2]
# ok: [node-1]
#
# PLAY [k8s_cluster:etcd] ********************************************************
# Saturday 03 June 2023  20:08:32 +0000 (0:00:01.582)       0:00:14.259 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.090)       0:00:14.349 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.051)       0:00:14.401 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.045)       0:00:14.446 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.078)       0:00:14.525 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.069)       0:00:14.595 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.077)       0:00:14.673 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.084)       0:00:14.757 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.043)       0:00:14.800 *********
# Saturday 03 June 2023  20:08:32 +0000 (0:00:00.081)       0:00:14.882 *********
# Saturday 03 June 2023  20:08:33 +0000 (0:00:00.940)       0:00:15.822 *********
#
# TASK [kubespray-defaults : Configure defaults] *********************************
# ok: [node-0] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# ok: [node-1] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# ok: [node-2] => {
#     "msg": "Check roles/kubespray-defaults/defaults/main.yml"
# }
# Saturday 03 June 2023  20:08:33 +0000 (0:00:00.142)       0:00:15.964 *********
# Saturday 03 June 2023  20:08:33 +0000 (0:00:00.108)       0:00:16.073 *********
#
# TASK [kubespray-defaults : create fallback_ips_base] ***************************
# ok: [node-0 -> localhost]
# Saturday 03 June 2023  20:08:33 +0000 (0:00:00.087)       0:00:16.160 *********
#
# TASK [kubespray-defaults : set fallback_ips] ***********************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:34 +0000 (0:00:00.124)       0:00:16.284 *********
# Saturday 03 June 2023  20:08:34 +0000 (0:00:00.071)       0:00:16.356 *********
# Saturday 03 June 2023  20:08:34 +0000 (0:00:00.082)       0:00:16.438 *********
# Saturday 03 June 2023  20:08:34 +0000 (0:00:00.108)       0:00:16.547 *********
#
# TASK [adduser : User | Create User Group] **************************************
# changed: [node-1]
# changed: [node-2]
# changed: [node-0]
# Saturday 03 June 2023  20:08:35 +0000 (0:00:00.752)       0:00:17.299 *********
#
# TASK [adduser : User | Create User] ********************************************
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:08:35 +0000 (0:00:00.834)       0:00:18.133 *********
#
# TASK [kubernetes/preinstall : Remove swapfile from /etc/fstab] *****************
# ok: [node-0] => (item=swap)
# ok: [node-1] => (item=swap)
# ok: [node-2] => (item=swap)
# ok: [node-0] => (item=none)
# ok: [node-1] => (item=none)
# ok: [node-2] => (item=none)
# Saturday 03 June 2023  20:08:37 +0000 (0:00:01.192)       0:00:19.326 *********
#
# TASK [kubernetes/preinstall : check swap] **************************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:37 +0000 (0:00:00.686)       0:00:20.012 *********
# Saturday 03 June 2023  20:08:37 +0000 (0:00:00.084)       0:00:20.097 *********
# Saturday 03 June 2023  20:08:37 +0000 (0:00:00.088)       0:00:20.185 *********
# Saturday 03 June 2023  20:08:38 +0000 (0:00:00.084)       0:00:20.270 *********
# Saturday 03 June 2023  20:08:38 +0000 (0:00:00.081)       0:00:20.351 *********
# Saturday 03 June 2023  20:08:38 +0000 (0:00:00.076)       0:00:20.428 *********
#
# TASK [kubernetes/preinstall : check if booted with ostree] *********************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:38 +0000 (0:00:00.630)       0:00:21.058 *********
#
# TASK [kubernetes/preinstall : set is_fedora_coreos] ****************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:39 +0000 (0:00:00.655)       0:00:21.713 *********
#
# TASK [kubernetes/preinstall : set is_fedora_coreos] ****************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:39 +0000 (0:00:00.196)       0:00:21.910 *********
#
# TASK [kubernetes/preinstall : check resolvconf] ********************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:40 +0000 (0:00:00.570)       0:00:22.481 *********
#
# TASK [kubernetes/preinstall : check existence of /etc/resolvconf/resolv.conf.d] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:40 +0000 (0:00:00.603)       0:00:23.084 *********
#
# TASK [kubernetes/preinstall : check status of /etc/resolv.conf] ****************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:41 +0000 (0:00:00.595)       0:00:23.680 *********
#
# TASK [kubernetes/preinstall : get content of /etc/resolv.conf] *****************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:42 +0000 (0:00:00.662)       0:00:24.343 *********
#
# TASK [kubernetes/preinstall : get currently configured nameservers] ************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:42 +0000 (0:00:00.281)       0:00:24.625 *********
#
# TASK [kubernetes/preinstall : Stop if /etc/resolv.conf not configured nameservers] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:42 +0000 (0:00:00.129)       0:00:24.754 *********
#
# TASK [kubernetes/preinstall : NetworkManager | Check if host has NetworkManager] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:43 +0000 (0:00:00.490)       0:00:25.244 *********
#
# TASK [kubernetes/preinstall : check systemd-resolved] **************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:43 +0000 (0:00:00.500)       0:00:25.745 *********
#
# TASK [kubernetes/preinstall : set default dns if remove_default_searchdomains is false] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:43 +0000 (0:00:00.117)       0:00:25.863 *********
#
# TASK [kubernetes/preinstall : set dns facts] ***********************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:43 +0000 (0:00:00.116)       0:00:25.980 *********
#
# TASK [kubernetes/preinstall : check if kubelet is configured] ******************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:44 +0000 (0:00:00.507)       0:00:26.488 *********
#
# TASK [kubernetes/preinstall : check if early DNS configuration stage] **********
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:44 +0000 (0:00:00.112)       0:00:26.601 *********
#
# TASK [kubernetes/preinstall : target resolv.conf files] ************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:44 +0000 (0:00:00.110)       0:00:26.711 *********
# Saturday 03 June 2023  20:08:44 +0000 (0:00:00.078)       0:00:26.790 *********
#
# TASK [kubernetes/preinstall : check if /etc/dhclient.conf exists] **************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.480)       0:00:27.271 *********
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.075)       0:00:27.347 *********
#
# TASK [kubernetes/preinstall : check if /etc/dhcp/dhclient.conf exists] *********
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.474)       0:00:27.821 *********
#
# TASK [kubernetes/preinstall : target dhclient conf file for /etc/dhcp/dhclient.conf] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.108)       0:00:27.930 *********
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.084)       0:00:28.014 *********
#
# TASK [kubernetes/preinstall : target dhclient hook file for Debian family] *****
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:45 +0000 (0:00:00.106)       0:00:28.121 *********
#
# TASK [kubernetes/preinstall : generate search domains to resolvconf] ***********
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.111)       0:00:28.232 *********
#
# TASK [kubernetes/preinstall : pick coredns cluster IP or default resolver] *****
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.170)       0:00:28.403 *********
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.084)       0:00:28.488 *********
#
# TASK [kubernetes/preinstall : generate nameservers for resolvconf, not including cluster DNS] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.111)       0:00:28.599 *********
#
# TASK [kubernetes/preinstall : gather os specific variables] ********************
# ok: [node-0] => (item=/home/cc/kubespray/roles/kubernetes/preinstall/vars/../vars/ubuntu.yml)
# ok: [node-1] => (item=/home/cc/kubespray/roles/kubernetes/preinstall/vars/../vars/ubuntu.yml)
# ok: [node-2] => (item=/home/cc/kubespray/roles/kubernetes/preinstall/vars/../vars/ubuntu.yml)
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.117)       0:00:28.717 *********
# Saturday 03 June 2023  20:08:46 +0000 (0:00:00.075)       0:00:28.792 *********
#
# TASK [kubernetes/preinstall : check /usr readonly] *****************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.487)       0:00:29.280 *********
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.082)       0:00:29.363 *********
#
# TASK [kubernetes/preinstall : Stop if either kube_control_plane or kube_node group is empty] ***
# ok: [node-0] => (item=kube_control_plane) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": "kube_control_plane",
#     "msg": "All assertions passed"
# }
# ok: [node-0] => (item=kube_node) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": "kube_node",
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.100)       0:00:29.463 *********
#
# TASK [kubernetes/preinstall : Stop if etcd group is empty in external etcd mode] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.075)       0:00:29.539 *********
#
# TASK [kubernetes/preinstall : Stop if non systemd OS type] *********************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.121)       0:00:29.660 *********
#
# TASK [kubernetes/preinstall : Stop if the os does not support] *****************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.124)       0:00:29.785 *********
#
# TASK [kubernetes/preinstall : Stop if unknown network plugin] ******************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.116)       0:00:29.902 *********
#
# TASK [kubernetes/preinstall : Stop if unsupported version of Kubernetes] *******
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.117)       0:00:30.019 *********
#
# TASK [kubernetes/preinstall : Stop if known booleans are set as strings (Use JSON format on CLI: -e "{'key': true }")] ***
# ok: [node-0] => (item={'name': 'download_run_once', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "download_run_once",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node-0] => (item={'name': 'deploy_netchecker', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "deploy_netchecker",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node-0] => (item={'name': 'download_always_pull', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "download_always_pull",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node-0] => (item={'name': 'helm_enabled', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "helm_enabled",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# ok: [node-0] => (item={'name': 'openstack_lbaas_enabled', 'value': False}) => {
#     "ansible_loop_var": "item",
#     "changed": false,
#     "item": {
#         "name": "openstack_lbaas_enabled",
#         "value": false
#     },
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:47 +0000 (0:00:00.169)       0:00:30.189 *********
#
# TASK [kubernetes/preinstall : Stop if even number of etcd hosts] ***************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:48 +0000 (0:00:00.114)       0:00:30.304 *********
#
# TASK [kubernetes/preinstall : Stop if memory is too small for masters] *********
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:48 +0000 (0:00:00.089)       0:00:30.394 *********
#
# TASK [kubernetes/preinstall : Stop if memory is too small for nodes] ***********
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:48 +0000 (0:00:00.114)       0:00:30.508 *********
# Saturday 03 June 2023  20:08:48 +0000 (0:00:00.083)       0:00:30.592 *********
#
# TASK [kubernetes/preinstall : Stop if ip var does not match local ips] *********
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:48 +0000 (0:00:00.123)       0:00:30.715 *********
#
# TASK [kubernetes/preinstall : Ensure ping package] *****************************
# ok: [node-1]
# ok: [node-0]
# ok: [node-2]
# Saturday 03 June 2023  20:08:49 +0000 (0:00:01.329)       0:00:32.045 *********
#
# TASK [kubernetes/preinstall : Stop if access_ip is not pingable] ***************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.491)       0:00:32.536 *********
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.077)       0:00:32.614 *********
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.090)       0:00:32.705 *********
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.083)       0:00:32.788 *********
#
# TASK [kubernetes/preinstall : Stop if bad hostname] ****************************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.111)       0:00:32.899 *********
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.084)       0:00:32.984 *********
#
# TASK [kubernetes/preinstall : Check that kube_service_addresses is a network range] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:50 +0000 (0:00:00.116)       0:00:33.100 *********
#
# TASK [kubernetes/preinstall : Check that kube_pods_subnet is a network range] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.117)       0:00:33.218 *********
#
# TASK [kubernetes/preinstall : Check that kube_pods_subnet does not collide with kube_service_addresses] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.109)       0:00:33.327 *********
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.039)       0:00:33.367 *********
#
# TASK [kubernetes/preinstall : Stop if unknown dns mode] ************************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.078)       0:00:33.445 *********
#
# TASK [kubernetes/preinstall : Stop if unknown kube proxy mode] *****************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.068)       0:00:33.513 *********
#
# TASK [kubernetes/preinstall : Stop if unknown cert_management] *****************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.064)       0:00:33.578 *********
#
# TASK [kubernetes/preinstall : Stop if unknown resolvconf_mode] *****************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.066)       0:00:33.645 *********
#
# TASK [kubernetes/preinstall : Stop if etcd deployment type is not host, docker or kubeadm] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-1] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# ok: [node-2] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.117)       0:00:33.763 *********
#
# TASK [kubernetes/preinstall : Stop if container manager is not docker, crio or containerd] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.069)       0:00:33.833 *********
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.094)       0:00:33.928 *********
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.050)       0:00:33.978 *********
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.048)       0:00:34.026 *********
# Saturday 03 June 2023  20:08:51 +0000 (0:00:00.085)       0:00:34.111 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.086)       0:00:34.198 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.089)       0:00:34.287 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.078)       0:00:34.366 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.043)       0:00:34.409 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.085)       0:00:34.495 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.076)       0:00:34.572 *********
# Saturday 03 June 2023  20:08:52 +0000 (0:00:00.091)       0:00:34.663 *********
#
# TASK [kubernetes/preinstall : Create kubernetes directories] *******************
# changed: [node-0] => (item=/etc/kubernetes)
# changed: [node-1] => (item=/etc/kubernetes)
# changed: [node-2] => (item=/etc/kubernetes)
# changed: [node-0] => (item=/etc/kubernetes/manifests)
# changed: [node-1] => (item=/etc/kubernetes/manifests)
# changed: [node-2] => (item=/etc/kubernetes/manifests)
# changed: [node-0] => (item=/usr/local/bin/kubernetes-scripts)
# changed: [node-1] => (item=/usr/local/bin/kubernetes-scripts)
# changed: [node-2] => (item=/usr/local/bin/kubernetes-scripts)
# changed: [node-0] => (item=/usr/libexec/kubernetes/kubelet-plugins/volume/exec)
# changed: [node-1] => (item=/usr/libexec/kubernetes/kubelet-plugins/volume/exec)
# changed: [node-2] => (item=/usr/libexec/kubernetes/kubelet-plugins/volume/exec)
# Saturday 03 June 2023  20:08:54 +0000 (0:00:01.702)       0:00:36.365 *********
#
# TASK [kubernetes/preinstall : Create other directories of root owner] **********
# changed: [node-0] => (item=/etc/kubernetes/ssl)
# changed: [node-1] => (item=/etc/kubernetes/ssl)
# changed: [node-2] => (item=/etc/kubernetes/ssl)
# ok: [node-0] => (item=/usr/local/bin)
# ok: [node-1] => (item=/usr/local/bin)
# ok: [node-2] => (item=/usr/local/bin)
# Saturday 03 June 2023  20:08:55 +0000 (0:00:00.898)       0:00:37.264 *********
#
# TASK [kubernetes/preinstall : Check if kubernetes kubeadm compat cert dir exists] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:08:55 +0000 (0:00:00.493)       0:00:37.757 *********
#
# TASK [kubernetes/preinstall : Create kubernetes kubeadm compat cert dir (kubernetes/kubeadm issue 1498)] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:08:56 +0000 (0:00:00.492)       0:00:38.250 *********
#
# TASK [kubernetes/preinstall : Create cni directories] **************************
# changed: [node-0] => (item=/etc/cni/net.d)
# changed: [node-1] => (item=/etc/cni/net.d)
# changed: [node-2] => (item=/etc/cni/net.d)
# changed: [node-0] => (item=/opt/cni/bin)
# changed: [node-1] => (item=/opt/cni/bin)
# changed: [node-2] => (item=/opt/cni/bin)
# Saturday 03 June 2023  20:08:56 +0000 (0:00:00.896)       0:00:39.146 *********
#
# TASK [kubernetes/preinstall : Create calico cni directories] *******************
# changed: [node-0] => (item=/var/lib/calico)
# changed: [node-1] => (item=/var/lib/calico)
# changed: [node-2] => (item=/var/lib/calico)
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.502)       0:00:39.649 *********
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.100)       0:00:39.750 *********
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.077)       0:00:39.827 *********
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.087)       0:00:39.915 *********
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.112)       0:00:40.027 *********
# Saturday 03 June 2023  20:08:57 +0000 (0:00:00.127)       0:00:40.154 *********
# Saturday 03 June 2023  20:08:58 +0000 (0:00:00.083)       0:00:40.238 *********
# Saturday 03 June 2023  20:08:58 +0000 (0:00:00.097)       0:00:40.336 *********
#
# TASK [kubernetes/preinstall : Write resolved.conf] *****************************
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:08:59 +0000 (0:00:01.150)       0:00:41.486 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.080)       0:00:41.567 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.076)       0:00:41.643 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.078)       0:00:41.722 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.078)       0:00:41.801 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.074)       0:00:41.875 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.077)       0:00:41.953 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.079)       0:00:42.032 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.071)       0:00:42.104 *********
# Saturday 03 June 2023  20:08:59 +0000 (0:00:00.080)       0:00:42.185 *********
# Saturday 03 June 2023  20:09:00 +0000 (0:00:00.078)       0:00:42.263 *********
#
# TASK [kubernetes/preinstall : Update package management cache (APT)] ***********
# changed: [node-0]
# changed: [node-2]
# changed: [node-1]
# Saturday 03 June 2023  20:09:12 +0000 (0:00:12.045)       0:00:54.309 *********
# Saturday 03 June 2023  20:09:12 +0000 (0:00:00.080)       0:00:54.389 *********
# Saturday 03 June 2023  20:09:12 +0000 (0:00:00.084)       0:00:54.474 *********
# Saturday 03 June 2023  20:09:12 +0000 (0:00:00.073)       0:00:54.548 *********
#
# TASK [kubernetes/preinstall : Update common_required_pkgs with ipvsadm when kube_proxy_mode is ipvs] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:12 +0000 (0:00:00.112)       0:00:54.660 *********
#
# TASK [kubernetes/preinstall : Install packages requirements] *******************
# changed: [node-2]
# changed: [node-1]
# changed: [node-0]
# Saturday 03 June 2023  20:09:28 +0000 (0:00:16.335)       0:01:10.996 *********
# Saturday 03 June 2023  20:09:28 +0000 (0:00:00.076)       0:01:11.072 *********
# Saturday 03 June 2023  20:09:28 +0000 (0:00:00.083)       0:01:11.156 *********
# Saturday 03 June 2023  20:09:29 +0000 (0:00:00.085)       0:01:11.241 *********
# Saturday 03 June 2023  20:09:29 +0000 (0:00:00.069)       0:01:11.311 *********
#
# TASK [kubernetes/preinstall : Clean previously used sysctl file locations] *****
# ok: [node-0] => (item=ipv4-ip_forward.conf)
# ok: [node-1] => (item=ipv4-ip_forward.conf)
# ok: [node-2] => (item=ipv4-ip_forward.conf)
# ok: [node-0] => (item=bridge-nf-call.conf)
# ok: [node-1] => (item=bridge-nf-call.conf)
# ok: [node-2] => (item=bridge-nf-call.conf)
# Saturday 03 June 2023  20:09:29 +0000 (0:00:00.863)       0:01:12.175 *********
#
# TASK [kubernetes/preinstall : Stat sysctl file configuration] ******************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:30 +0000 (0:00:00.507)       0:01:12.682 *********
#
# TASK [kubernetes/preinstall : Change sysctl file path to link source if linked] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:30 +0000 (0:00:00.114)       0:01:12.797 *********
#
# TASK [kubernetes/preinstall : Make sure sysctl file path folder exists] ********
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:31 +0000 (0:00:00.483)       0:01:13.281 *********
#
# TASK [kubernetes/preinstall : Enable ip forwarding] ****************************
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:32 +0000 (0:00:01.682)       0:01:14.963 *********
# Saturday 03 June 2023  20:09:32 +0000 (0:00:00.085)       0:01:15.049 *********
#
# TASK [kubernetes/preinstall : Check if we need to set fs.may_detach_mounts] ****
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:33 +0000 (0:00:00.494)       0:01:15.543 *********
# Saturday 03 June 2023  20:09:33 +0000 (0:00:00.087)       0:01:15.631 *********
#
# TASK [kubernetes/preinstall : Ensure kube-bench parameters are set] ************
# changed: [node-0] => (item={'name': 'kernel.keys.root_maxbytes', 'value': 25000000})
# changed: [node-1] => (item={'name': 'kernel.keys.root_maxbytes', 'value': 25000000})
# changed: [node-2] => (item={'name': 'kernel.keys.root_maxbytes', 'value': 25000000})
# changed: [node-0] => (item={'name': 'kernel.keys.root_maxkeys', 'value': 1000000})
# changed: [node-1] => (item={'name': 'kernel.keys.root_maxkeys', 'value': 1000000})
# changed: [node-0] => (item={'name': 'kernel.panic', 'value': 10})
# changed: [node-1] => (item={'name': 'kernel.panic', 'value': 10})
# changed: [node-0] => (item={'name': 'kernel.panic_on_oops', 'value': 1})
# changed: [node-1] => (item={'name': 'kernel.panic_on_oops', 'value': 1})
# changed: [node-2] => (item={'name': 'kernel.keys.root_maxkeys', 'value': 1000000})
# changed: [node-0] => (item={'name': 'vm.overcommit_memory', 'value': 1})
# changed: [node-1] => (item={'name': 'vm.overcommit_memory', 'value': 1})
# changed: [node-2] => (item={'name': 'kernel.panic', 'value': 10})
# changed: [node-0] => (item={'name': 'vm.panic_on_oom', 'value': 0})
# changed: [node-1] => (item={'name': 'vm.panic_on_oom', 'value': 0})
# changed: [node-2] => (item={'name': 'kernel.panic_on_oops', 'value': 1})
# changed: [node-2] => (item={'name': 'vm.overcommit_memory', 'value': 1})
# changed: [node-2] => (item={'name': 'vm.panic_on_oom', 'value': 0})
# Saturday 03 June 2023  20:09:37 +0000 (0:00:03.688)       0:01:19.319 *********
#
# TASK [kubernetes/preinstall : Check dummy module] ******************************
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:37 +0000 (0:00:00.753)       0:01:20.072 *********
# Saturday 03 June 2023  20:09:37 +0000 (0:00:00.075)       0:01:20.148 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.085)       0:01:20.233 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.075)       0:01:20.309 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.078)       0:01:20.388 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.081)       0:01:20.470 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.083)       0:01:20.553 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.079)       0:01:20.633 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.082)       0:01:20.716 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.090)       0:01:20.806 *********
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.092)       0:01:20.898 *********
#
# TASK [kubernetes/preinstall : Hosts | create list from inventory] **************
# ok: [node-0 -> localhost]
# Saturday 03 June 2023  20:09:38 +0000 (0:00:00.226)       0:01:21.125 *********
#
# TASK [kubernetes/preinstall : Hosts | populate inventory into hosts file] ******
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:39 +0000 (0:00:00.625)       0:01:21.751 *********
# Saturday 03 June 2023  20:09:39 +0000 (0:00:00.083)       0:01:21.834 *********
#
# TASK [kubernetes/preinstall : Hosts | Retrieve hosts file content] *************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:40 +0000 (0:00:00.447)       0:01:22.281 *********
#
# TASK [kubernetes/preinstall : Hosts | Extract existing entries for localhost from hosts file] ***
# ok: [node-0] => (item=127.0.0.1 localhost)
# ok: [node-0] => (item=::1 localhost ip6-localhost ip6-loopback)
# ok: [node-1] => (item=127.0.0.1 localhost)
# ok: [node-2] => (item=127.0.0.1 localhost)
# ok: [node-2] => (item=::1 localhost ip6-localhost ip6-loopback)
# ok: [node-1] => (item=::1 localhost ip6-localhost ip6-loopback)
# Saturday 03 June 2023  20:09:40 +0000 (0:00:00.274)       0:01:22.556 *********
#
# TASK [kubernetes/preinstall : Hosts | Update target hosts file entries dict with required entries] ***
# ok: [node-0] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-1] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-0] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# ok: [node-1] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# ok: [node-2] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-2] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# Saturday 03 June 2023  20:09:40 +0000 (0:00:00.155)       0:01:22.711 *********
#
# TASK [kubernetes/preinstall : Hosts | Update (if necessary) hosts file] ********
# changed: [node-0] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# changed: [node-1] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# changed: [node-2] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# changed: [node-0] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# changed: [node-1] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# changed: [node-2] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# Saturday 03 June 2023  20:09:41 +0000 (0:00:00.929)       0:01:23.641 *********
#
# TASK [kubernetes/preinstall : Update facts] ************************************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:42 +0000 (0:00:00.878)       0:01:24.520 *********
#
# TASK [kubernetes/preinstall : Configure dhclient to supersede search/domain/nameservers] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:42 +0000 (0:00:00.505)       0:01:25.025 *********
#
# TASK [kubernetes/preinstall : Configure dhclient hooks for resolv.conf (non-RH)] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:43 +0000 (0:00:00.841)       0:01:25.867 *********
# Saturday 03 June 2023  20:09:43 +0000 (0:00:00.088)       0:01:25.956 *********
# Saturday 03 June 2023  20:09:43 +0000 (0:00:00.081)       0:01:26.037 *********
# Saturday 03 June 2023  20:09:43 +0000 (0:00:00.080)       0:01:26.118 *********
# Saturday 03 June 2023  20:09:43 +0000 (0:00:00.000)       0:01:26.119 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | propagate resolvconf to k8s components] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:09:44 +0000 (0:00:00.469)       0:01:26.589 *********
# Saturday 03 June 2023  20:09:44 +0000 (0:00:00.081)       0:01:26.670 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | kube-apiserver configured] ***
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:09:44 +0000 (0:00:00.423)       0:01:27.093 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | kube-controller configured] ***
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.434)       0:01:27.527 *********
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.083)       0:01:27.611 *********
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.080)       0:01:27.692 *********
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.092)       0:01:27.784 *********
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.080)       0:01:27.865 *********
# Saturday 03 June 2023  20:09:45 +0000 (0:00:00.080)       0:01:27.945 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | Restart systemd-resolved] ***
# changed: [node-2]
# changed: [node-1]
# changed: [node-0]
# Saturday 03 June 2023  20:09:46 +0000 (0:00:01.150)       0:01:29.095 *********
#
# TASK [kubernetes/preinstall : Check if we are running inside a Azure VM] *******
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.480)       0:01:29.576 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.091)       0:01:29.668 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.089)       0:01:29.757 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.076)       0:01:29.834 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.077)       0:01:29.911 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.093)       0:01:30.005 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.078)       0:01:30.084 *********
# Saturday 03 June 2023  20:09:47 +0000 (0:00:00.080)       0:01:30.164 *********
#
# TASK [Run calico checks] *******************************************************
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.428)       0:01:30.592 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (ipip)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.091)       0:01:30.684 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (ipip_mode)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.085)       0:01:30.769 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (calcio_ipam_autoallocateblocks)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.082)       0:01:30.851 *********
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.058)       0:01:30.910 *********
#
# TASK [network_plugin/calico : Stop if supported Calico versions] ***************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:48 +0000 (0:00:00.082)       0:01:30.992 *********
#
# TASK [network_plugin/calico : Check if calicoctl.sh exists] ********************
# ok: [node-0]
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.290)       0:01:31.283 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.049)       0:01:31.333 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.051)       0:01:31.384 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.050)       0:01:31.435 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.054)       0:01:31.489 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.052)       0:01:31.542 *********
#
# TASK [network_plugin/calico : Check vars defined correctly] ********************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.079)       0:01:31.622 *********
#
# TASK [network_plugin/calico : Check calico network backend defined correctly] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.081)       0:01:31.703 *********
#
# TASK [network_plugin/calico : Check ipip and vxlan mode defined correctly] *****
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.081)       0:01:31.785 *********
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.053)       0:01:31.839 *********
#
# TASK [network_plugin/calico : Check ipip and vxlan mode if simultaneously enabled] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:09:49 +0000 (0:00:00.082)       0:01:31.921 *********
#
# TASK [network_plugin/calico : Get Calico default-pool configuration] ***********
# ok: [node-0]
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.286)       0:01:32.208 *********
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.050)       0:01:32.258 *********
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.071)       0:01:32.330 *********
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.053)       0:01:32.383 *********
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.051)       0:01:32.435 *********
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.109)       0:01:32.545 *********
#
# TASK [container-engine/validate-container-engine : validate-container-engine | check if fedora coreos] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.508)       0:01:33.053 *********
#
# TASK [container-engine/validate-container-engine : validate-container-engine | set is_ostree] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:50 +0000 (0:00:00.113)       0:01:33.167 *********
#
# TASK [container-engine/validate-container-engine : Ensure kubelet systemd unit exists] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:09:51 +0000 (0:00:00.475)       0:01:33.642 *********
#
# TASK [container-engine/validate-container-engine : Populate service facts] *****
# ok: [node-2]
# ok: [node-1]
# ok: [node-0]
# Saturday 03 June 2023  20:09:57 +0000 (0:00:05.552)       0:01:39.195 *********
#
# ...
# Saturday 03 June 2023  20:21:56 +0000 (0:00:00.109)       0:13:38.909 *********
# Saturday 03 June 2023  20:21:56 +0000 (0:00:00.101)       0:13:39.010 *********
# Saturday 03 June 2023  20:21:56 +0000 (0:00:00.098)       0:13:39.109 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.104)       0:13:39.213 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.114)       0:13:39.328 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.104)       0:13:39.432 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.101)       0:13:39.534 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.096)       0:13:39.630 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.105)       0:13:39.735 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.102)       0:13:39.838 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.103)       0:13:39.941 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.115)       0:13:40.057 *********
# Saturday 03 June 2023  20:21:57 +0000 (0:00:00.102)       0:13:40.160 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.117)       0:13:40.277 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.128)       0:13:40.406 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.111)       0:13:40.518 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.100)       0:13:40.618 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.094)       0:13:40.712 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.185)       0:13:40.898 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.096)       0:13:40.995 *********
# Saturday 03 June 2023  20:21:58 +0000 (0:00:00.114)       0:13:41.109 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.096)       0:13:41.205 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.149)       0:13:41.355 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.100)       0:13:41.455 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.103)       0:13:41.559 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.105)       0:13:41.665 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.102)       0:13:41.767 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.105)       0:13:41.873 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.102)       0:13:41.976 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.102)       0:13:42.079 *********
# Saturday 03 June 2023  20:21:59 +0000 (0:00:00.111)       0:13:42.190 *********
# Saturday 03 June 2023  20:22:00 +0000 (0:00:00.109)       0:13:42.300 *********
# Saturday 03 June 2023  20:22:00 +0000 (0:00:00.101)       0:13:42.402 *********
# Saturday 03 June 2023  20:22:00 +0000 (0:00:00.112)       0:13:42.514 *********
#
# TASK [kubernetes/preinstall : Hosts | create list from inventory] **************
# ok: [node-0 -> localhost]
# Saturday 03 June 2023  20:22:00 +0000 (0:00:00.342)       0:13:42.857 *********
#
# TASK [kubernetes/preinstall : Hosts | populate inventory into hosts file] ******
# ok: [node-1]
# ok: [node-0]
# ok: [node-2]
# Saturday 03 June 2023  20:22:01 +0000 (0:00:00.543)       0:13:43.400 *********
# Saturday 03 June 2023  20:22:01 +0000 (0:00:00.100)       0:13:43.501 *********
#
# TASK [kubernetes/preinstall : Hosts | Retrieve hosts file content] *************
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:22:01 +0000 (0:00:00.507)       0:13:44.009 *********
#
# TASK [kubernetes/preinstall : Hosts | Extract existing entries for localhost from hosts file] ***
# ok: [node-0] => (item=127.0.0.1 localhost localhost.localdomain)
# ok: [node-1] => (item=127.0.0.1 localhost localhost.localdomain)
# ok: [node-0] => (item=::1 ip6-localhost ip6-loopback localhost6 localhost6.localdomain)
# ok: [node-1] => (item=::1 ip6-localhost ip6-loopback localhost6 localhost6.localdomain)
# ok: [node-2] => (item=127.0.0.1 localhost localhost.localdomain)
# ok: [node-2] => (item=::1 ip6-localhost ip6-loopback localhost6 localhost6.localdomain)
# Saturday 03 June 2023  20:22:02 +0000 (0:00:00.435)       0:13:44.444 *********
#
# TASK [kubernetes/preinstall : Hosts | Update target hosts file entries dict with required entries] ***
# ok: [node-0] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-0] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# ok: [node-1] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-1] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# ok: [node-2] => (item={'key': '127.0.0.1', 'value': {'expected': ['localhost', 'localhost.localdomain']}})
# ok: [node-2] => (item={'key': '::1', 'value': {'expected': ['localhost6', 'localhost6.localdomain'], 'unexpected': ['localhost', 'localhost.localdomain']}})
# Saturday 03 June 2023  20:22:02 +0000 (0:00:00.188)       0:13:44.633 *********
#
# TASK [kubernetes/preinstall : Hosts | Update (if necessary) hosts file] ********
# ok: [node-0] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# ok: [node-1] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# ok: [node-2] => (item={'key': '127.0.0.1', 'value': ['localhost', 'localhost.localdomain']})
# ok: [node-0] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# ok: [node-1] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# ok: [node-2] => (item={'key': '::1', 'value': ['ip6-localhost', 'ip6-loopback', 'localhost6', 'localhost6.localdomain']})
# Saturday 03 June 2023  20:22:03 +0000 (0:00:01.028)       0:13:45.662 *********
# Saturday 03 June 2023  20:22:03 +0000 (0:00:00.104)       0:13:45.767 *********
#
# TASK [kubernetes/preinstall : Configure dhclient to supersede search/domain/nameservers] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:22:04 +0000 (0:00:00.535)       0:13:46.302 *********
#
# TASK [kubernetes/preinstall : Configure dhclient hooks for resolv.conf (non-RH)] ***
# ok: [node-0]
# ok: [node-1]
# ok: [node-2]
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.941)       0:13:47.243 *********
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.113)       0:13:47.357 *********
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.101)       0:13:47.458 *********
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.108)       0:13:47.567 *********
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.000)       0:13:47.567 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | propagate resolvconf to k8s components] ***
# changed: [node-0]
# changed: [node-2]
# changed: [node-1]
# Saturday 03 June 2023  20:22:05 +0000 (0:00:00.614)       0:13:48.181 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | reload kubelet] **********
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:22:06 +0000 (0:00:00.979)       0:13:49.160 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | kube-apiserver configured] ***
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:22:07 +0000 (0:00:00.587)       0:13:49.748 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | kube-controller configured] ***
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:22:08 +0000 (0:00:00.522)       0:13:50.271 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | restart kube-controller-manager docker] ***
# changed: [node-0]
# changed: [node-1]
# Saturday 03 June 2023  20:22:09 +0000 (0:00:00.970)       0:13:51.241 *********
# Saturday 03 June 2023  20:22:09 +0000 (0:00:00.126)       0:13:51.368 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | restart kube-apiserver docker] ***
# changed: [node-1]
# changed: [node-0]
# Saturday 03 June 2023  20:22:10 +0000 (0:00:00.936)       0:13:52.304 *********
# Saturday 03 June 2023  20:22:10 +0000 (0:00:00.106)       0:13:52.410 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | wait for the apiserver to be running] ***
# ok: [node-0]
# ok: [node-1]
# Saturday 03 June 2023  20:22:10 +0000 (0:00:00.780)       0:13:53.191 *********
#
# RUNNING HANDLER [kubernetes/preinstall : Preinstall | Restart systemd-resolved] ***
# changed: [node-0]
# changed: [node-1]
# changed: [node-2]
# Saturday 03 June 2023  20:22:12 +0000 (0:00:01.051)       0:13:54.242 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.136)       0:13:54.378 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.133)       0:13:54.511 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.110)       0:13:54.622 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.108)       0:13:54.730 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.095)       0:13:54.826 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.102)       0:13:54.928 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.094)       0:13:55.023 *********
# Saturday 03 June 2023  20:22:12 +0000 (0:00:00.109)       0:13:55.132 *********
#
# TASK [Run calico checks] *******************************************************
# Saturday 03 June 2023  20:22:13 +0000 (0:00:00.468)       0:13:55.600 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (ipip)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:13 +0000 (0:00:00.239)       0:13:55.839 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (ipip_mode)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:13 +0000 (0:00:00.220)       0:13:56.060 *********
#
# TASK [network_plugin/calico : Stop if legacy encapsulation variables are detected (calcio_ipam_autoallocateblocks)] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:14 +0000 (0:00:00.239)       0:13:56.299 *********
# Saturday 03 June 2023  20:22:14 +0000 (0:00:00.068)       0:13:56.368 *********
#
# TASK [network_plugin/calico : Stop if supported Calico versions] ***************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:14 +0000 (0:00:00.103)       0:13:56.471 *********
#
# TASK [network_plugin/calico : Check if calicoctl.sh exists] ********************
# ok: [node-0]
# Saturday 03 June 2023  20:22:14 +0000 (0:00:00.345)       0:13:56.816 *********
# FAILED - RETRYING: [node-0]: Check if calico ready (5 retries left).
# FAILED - RETRYING: [node-0]: Check if calico ready (4 retries left).
# FAILED - RETRYING: [node-0]: Check if calico ready (3 retries left).
#
# TASK [network_plugin/calico : Check if calico ready] ***************************
# changed: [node-0]
# Saturday 03 June 2023  20:22:45 +0000 (0:00:31.351)       0:14:28.168 *********
#
# TASK [network_plugin/calico : Get current calico version] **********************
# ok: [node-0]
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.449)       0:14:28.617 *********
#
# TASK [network_plugin/calico : Assert that current calico version is enough for upgrade] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.118)       0:14:28.736 *********
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.078)       0:14:28.814 *********
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.079)       0:14:28.894 *********
#
# TASK [network_plugin/calico : Check vars defined correctly] ********************
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.108)       0:14:29.002 *********
#
# TASK [network_plugin/calico : Check calico network backend defined correctly] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:46 +0000 (0:00:00.115)       0:14:29.118 *********
#
# TASK [network_plugin/calico : Check ipip and vxlan mode defined correctly] *****
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.107)       0:14:29.225 *********
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.084)       0:14:29.309 *********
#
# TASK [network_plugin/calico : Check ipip and vxlan mode if simultaneously enabled] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.131)       0:14:29.441 *********
#
# TASK [network_plugin/calico : Get Calico default-pool configuration] ***********
# ok: [node-0]
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.446)       0:14:29.887 *********
#
# TASK [network_plugin/calico : Set calico_pool_conf] ****************************
# ok: [node-0]
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.118)       0:14:30.006 *********
#
# TASK [network_plugin/calico : Check if inventory match current cluster configuration] ***
# ok: [node-0] => {
#     "changed": false,
#     "msg": "All assertions passed"
# }
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.109)       0:14:30.115 *********
# Saturday 03 June 2023  20:22:47 +0000 (0:00:00.074)       0:14:30.190 *********
# Saturday 03 June 2023  20:22:48 +0000 (0:00:00.092)       0:14:30.282 *********
#
# PLAY RECAP *********************************************************************
# localhost                  : ok=3    changed=0    unreachable=0    failed=0    skipped=0    rescued=0    ignored=0
# node-0                     : ok=753  changed=150  unreachable=0    failed=0    skipped=1275 rescued=0    ignored=8
# node-1                     : ok=653  changed=136  unreachable=0    failed=0    skipped=1123 rescued=0    ignored=3
# node-2                     : ok=536  changed=112  unreachable=0    failed=0    skipped=796  rescued=0    ignored=2
#
# Saturday 03 June 2023  20:22:48 +0000 (0:00:00.162)       0:14:30.445 *********
# ===============================================================================
# kubernetes/kubeadm : Join to cluster ----------------------------------- 33.26s
# network_plugin/calico : Check if calico ready -------------------------- 31.35s
# container-engine/docker : ensure docker packages are installed --------- 27.29s
# kubernetes/control-plane : Joining control plane node to the cluster. -- 23.86s
# etcd : reload etcd ----------------------------------------------------- 20.98s
# kubernetes/preinstall : Install packages requirements ------------------ 16.34s
# kubernetes/control-plane : kubeadm | Initialize first master ----------- 14.75s
# etcd : Gen_certs | Write etcd member/admin and kube_control_plane client certs to other etcd nodes -- 14.26s
# kubernetes/preinstall : Update package management cache (APT) ---------- 12.05s
# download : download_container | Download image if required -------------- 9.97s
# download : download_container | Download image if required -------------- 9.95s
# kubernetes-apps/ansible : Kubernetes Apps | Start Resources ------------- 9.37s
# etcd : Refresh Time Fact ------------------------------------------------ 9.06s
# download : download_container | Download image if required -------------- 8.55s
# kubernetes-apps/ansible : Kubernetes Apps | Lay Down CoreDNS templates --- 7.55s
# download : download_container | Download image if required -------------- 7.46s
# kubernetes-apps/metrics_server : Metrics Server | Apply manifests ------- 6.88s
# download : download_container | Download image if required -------------- 6.43s
# download : download_container | Download image if required -------------- 6.14s
# container-engine/docker : ensure docker-ce repository is enabled -------- 6.14s
# <Result cmd='source myenv/bin/activate; cd kubespray; ansible-playbook -i inventory/mycluster/hosts.yaml  --become --become-user=root cluster.yml' exited=0>

# %% [markdown]
# #### Provide relevent access to kubectl and Docker

# %%
import chi.ssh
remote = chi.ssh.Remote(nodes[0])
remote.run("sudo cp -R /root/.kube /home/cc/.kube; sudo chown -R cc /home/cc/.kube; sudo chgrp -R cc /home/cc/.kube")
# Out:
# <Result cmd='sudo cp -R /root/.kube /home/cc/.kube; sudo chown -R cc /home/cc/.kube; sudo chgrp -R cc /home/cc/.kube' exited=0>

# %%
import chi.ssh
for node_ip in nodes.values():
    remote = chi.ssh.Remote(node_ip)
    remote.run("sudo ufw allow 32000")
# Out:
# Rule added
# Rule added (v6)
# Rule added
# Rule added (v6)
# Rule added
# Rule added (v6)

# %%
remote = chi.ssh.Remote(nodes[0])
remote.run("sudo groupadd docker; sudo usermod -aG docker $USER")
remote = chi.ssh.Remote(nodes[0])
# Out:
# groupadd: group 'docker' already exists

# %% [markdown]
# #### Start local Docker registry

# %%
remote.run("docker run -d -p 5000:5000 --restart always --name registry registry:2")
for node_ip in nodes.values():
    remote = chi.ssh.Remote(node_ip)
    remote.run("sudo wget https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/daemon.json -O /etc/docker/daemon.json")
    remote.run("sudo service docker restart")
# Out:
# Unable to find image 'registry:2' locally
# 2: Pulling from library/registry
# 8a49fdb3b6a5: Pulling fs layer
# 58116d8bf569: Pulling fs layer
# 4cb4a93be51c: Pulling fs layer
# cbdeff65a266: Pulling fs layer
# 6b102b34ed3d: Pulling fs layer
# cbdeff65a266: Waiting
# 6b102b34ed3d: Waiting
# 58116d8bf569: Download complete
# 8a49fdb3b6a5: Download complete
# 4cb4a93be51c: Verifying Checksum
# 4cb4a93be51c: Download complete
# cbdeff65a266: Verifying Checksum
# cbdeff65a266: Download complete
# 6b102b34ed3d: Verifying Checksum
# 6b102b34ed3d: Download complete
# 8a49fdb3b6a5: Pull complete
# 58116d8bf569: Pull complete
# 4cb4a93be51c: Pull complete
# cbdeff65a266: Pull complete
# 6b102b34ed3d: Pull complete
# Digest: sha256:20d084723c951e377e1a2a5b3df316173a845e300d57ccdd8ae3ab2da3439746
# Status: Downloaded newer image for registry:2
# 2063584c0e0e07324afb46e97a4c9e465b72adbacc49e5707c416d8952402a06
# --2023-06-03 20:31:49--  https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/daemon.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65 [text/plain]
# Saving to: ‘/etc/docker/daemon.json’
#
#      0K                                                       100% 2.14M=0s
#
# 2023-06-03 20:31:49 (2.14 MB/s) - ‘/etc/docker/daemon.json’ saved [65/65]
#
# --2023-06-03 20:32:00--  https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/daemon.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65 [text/plain]
# Saving to: ‘/etc/docker/daemon.json’
#
#      0K                                                       100% 2.86M=0s
#
# 2023-06-03 20:32:00 (2.86 MB/s) - ‘/etc/docker/daemon.json’ saved [65/65]
#
# --2023-06-03 20:32:09--  https://raw.githubusercontent.com/teaching-on-testbeds/k8s-ml/main/config/daemon.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65 [text/plain]
# Saving to: ‘/etc/docker/daemon.json’
#
#      0K                                                       100% 2.46M=0s
#
# 2023-06-03 20:32:10 (2.46 MB/s) - ‘/etc/docker/daemon.json’ saved [65/65]

# %% [markdown]
# #### Check installation

# %%
remote = chi.ssh.Remote(nodes[0])
remote.run("kubectl get nodes")
# Out:
# NAME     STATUS   ROLES           AGE   VERSION
# node-0   Ready    control-plane   14m   v1.26.5
# node-1   Ready    control-plane   14m   v1.26.5
# node-2   Ready    <none>          13m   v1.26.5
# <Result cmd='kubectl get nodes' exited=0>

# %%
remote.run("docker run hello-world")
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
# 719385e32844: Pulling fs layer
# 719385e32844: Download complete
# 719385e32844: Pull complete
# Digest: sha256:fc6cf906cbfa013e80938cdf0bb199fbdbb86d6e3e013783e5a766f50f5dbce0
# Status: Downloaded newer image for hello-world:latest
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/
# <Result cmd='docker run hello-world' exited=0>

# %% [markdown]
# # Delete resources

# %% [markdown]
# ### Delete server

# %%
if True: 
    for i in servers:
      chi.server.delete_server(i.id)

# %% [markdown]
# ### Delete network and routers

# %%
router_id = router['id']
subnet_id = subnet['id']

try:
    result = chi.network.remove_subnet_from_router(router_id, subnet_id)
except Exception as e:
    print(f"detach_router_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_router(router_id)
except Exception as e:
    print(f"delete_router_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_subnet(subnet_id)
except Exception as e:
    print(f"delete_subnet_by_name error: {str(e)}")
    pass

try:
    result = chi.network.delete_network(network_id)
except Exception as e:
    print(f"delete_network_by_name error: {str(e)}")
    pass
